# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/Google_cloud/blob/main/VertexAI/PromptDesignInVertexAI/ChallengeLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge Lab

# %% [markdown]
# ## Task 1. Build a Gemini image analysis tool

# %% [markdown]
# You are a creative product copywriter and nature-inspired storyteller.
# Analyze the following product image and generate three types of text:
#
# 1. Short, descriptive text (1–2 sentences) that highlights simple product details visible in the image.
# 2. Catchy phrases (4–8 words) suitable for advertisements, focusing on appeal and memorability.
# 3. A poetic description (2–3 sentences) that sets a mood for a nature-focused campaign.
#
# Image: {image_file_path}
#
# Rules:
# - Base your writing on visible elements of the image.
# - Use sensory and nature-inspired language where appropriate.
# - Keep all text audience-friendly and brand-appropriate.
# - Provide multiple options for each category.

# %% [markdown]
# ## Task 2. Build a Gemini tagline generator

# %% [markdown]
# Cymbal Direct is partnering with an outdoor gear retailer. They're launching a new line of products designed to encourage young people to explore the outdoors. Help them create catchy taglines for this product line.

# %% [markdown]
# You are a creative tagline generator for an outdoor gear brand.
#
# Generate 5 diverse tagline options for the product described below.
#
# Input parameters:
# - Product attributes: {product_attributes}
# - Target audience: {target_audience}
# - Emotional resonance: {emotional_resonance}
# - Style: {style}  // e.g., minimalist, playful, bold, poetic
#
# Guidelines:
# - Keep taglines short (4–8 words).
# - Highlight both product features and the desired feeling.
# - Make them catchy, brand-friendly, and easy to remember.
# - Avoid technical claims unless they are explicitly stated in the attributes.
#
# Return the results as a numbered list.

# %% [markdown]
# Write a tagline for a durable backpack designed for hikers that makes them feel prepared. Consider styles like minimalist.
#
#
# Built for the Journey: Your Adventure Essentials.

# %% [markdown]
# Write a tagline for a lightweight rain jacket designed for teens who love spontaneous adventures. Consider styles like playful.
#
#
# Rain or Shine, Let’s Go!

# %% [markdown]
# Product attributes: waterproof, breathable, lightweight
# Target audience: young adventurers
# Emotional resonance: empowered, unstoppable
# Style: bold

# %% [markdown]
# ## Task 3. Experiment with image analysis code

# %% [markdown]
# ## Task 4. Experiment with tagline generation code
