# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/Google_cloud/blob/main/GenerativeAI/Build_Real_World_AI_Applications_with_Gemini_and_Imagen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Build Real-World AI Applications with Gemini and Imagen

# %% [markdown]
# ## Build an AI Image Recognition app using Gemini on Vertext AI

# %% [markdown]
# ## Build an AI Image Generator app using Imagen on Vertex AI

# %% [markdown]
# ## Build an application to send Chat Prompts using the Gemini model

# %% [markdown]
# ## Build a Multi-Modal GenAI Application: Challenge Lab
