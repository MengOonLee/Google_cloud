# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/Google_cloud/blob/main/BigQuery/MultimodalVectorSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement Multimodal Vector Search with BigQuery

# %% [markdown]
# ## Develop Code with Gemini in BigQuery
